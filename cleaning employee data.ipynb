# %%
#Import libraries
import pandas as pd

#Load dataset
df = pd.read_excel("C:/Users/VictoriaAfatsawo/Desktop/Python_cleaning emp_data/employee_survey.xlsx")

df.head()
# Out:
#    EmpID  Gender  Age MaritalStatus        JobLevel  Experience       Dept  \
# 0      6    Male   32       Married             Mid           7         IT
# 1     11  Female   34       Married             Mid          12    Finance
# 2     33  Female   23        Single  Intern/Fresher           1  Marketing
# 3     20  Female   29       Married          Junior           6         IT
# 4     28   Other   23        Single          Junior           1      Sales
#
#      EmpType  WLB  WorkEnv  ...  SleepHours       CommuteMode  \
# 0  Full-Time    1        1  ...         7.6               Car
# 1  Full-Time    1        1  ...         7.9               Car
# 2  Full-Time    2        4  ...         6.5         Motorbike
# 3   Contract    2        2  ...         7.5  Public Transport
# 4  Part-Time    3        1  ...         4.9               Car
#
#    CommuteDistance  NumCompanies TeamSize  NumReports  EduLevel  haveOT  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3025 entries, 0 to 3024
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   EmpID                  3025 non-null   int64
#  1   Gender                 3025 non-null   object
#  2   Age                    3025 non-null   int64
#  3   MaritalStatus          3025 non-null   object
#  4   JobLevel               3025 non-null   object
#  5   Experience             3025 non-null   int64
#  6   Dept                   3025 non-null   object
#  7   EmpType                3025 non-null   object
#  8   WLB                    3025 non-null   int64
#  9   WorkEnv                3025 non-null   int64
#  10  PhysicalActivityHours  3025 non-null   float64
#  11  Workload               3025 non-null   int64
#  12  Stress                 3025 non-null   int64
#  13  SleepHours             3025 non-null   float64
# ...

# %%
#Check duplicates 
df.duplicated().sum
# Out:
# <bound method Series.sum of 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3020    False
# 3021    False
# 3022    False
# 3023    False
# 3024    False
# Length: 3025, dtype: bool>

# %%
#Check missing values

df.isnull().sum()
# Out:
# EmpID                    0
# Gender                   0
# Age                      0
# MaritalStatus            0
# JobLevel                 0
# Experience               0
# Dept                     0
# EmpType                  0
# WLB                      0
# WorkEnv                  0
# PhysicalActivityHours    0
# Workload                 0
# Stress                   0
# SleepHours               0
# CommuteMode              0
# CommuteDistance          0
# NumCompanies             0
# TeamSize                 0
# NumReports               0
# EduLevel                 0
# haveOT                   0
# TrainingHoursPerYear     0
# JobSatisfaction          0
# dtype: int64

# %%
#Chech extra spaces
df.apply(lambda col: col.astype(str).str.contains(r'^\s+|\s+$|\s{2,}').sum())
# Out:
# EmpID                    0
# Gender                   0
# Age                      0
# MaritalStatus            0
# JobLevel                 0
# Experience               0
# Dept                     0
# EmpType                  0
# WLB                      0
# WorkEnv                  0
# PhysicalActivityHours    0
# Workload                 0
# Stress                   0
# SleepHours               0
# CommuteMode              0
# CommuteDistance          0
# NumCompanies             0
# TeamSize                 0
# NumReports               0
# EduLevel                 0
# haveOT                   0
# TrainingHoursPerYear     0
# JobSatisfaction          0
# dtype: int64

# %%
#Convert data type
df[["Gender", "MaritalStatus", "JobLevel", "Dept", "EmpType", "CommuteMode", "EduLevel","haveOT"]] = df[["Gender", "MaritalStatus", "JobLevel", "Dept", "EmpType","CommuteMode", "EduLevel", "haveOT" ]].astype("string")
df.dtypes
# Out:
# EmpID                             int64
# Gender                   string[python]
# Age                               int64
# MaritalStatus            string[python]
# JobLevel                 string[python]
# Experience                        int64
# Dept                     string[python]
# EmpType                  string[python]
# WLB                               int64
# WorkEnv                           int64
# PhysicalActivityHours           float64
# Workload                          int64
# Stress                            int64
# SleepHours                      float64
# CommuteMode              string[python]
# CommuteDistance                   int64
# NumCompanies                      int64
# TeamSize                          int64
# NumReports                        int64
# EduLevel                 string[python]
# haveOT                   string[python]
# TrainingHoursPerYear            float64
# JobSatisfaction                   int64
# dtype: object

# %%
#inconsistent capitalization
df["Gender"] = df["Gender"].str.title()
df["MaritalStatus"] = df["MaritalStatus"].str.title()
df["JobLevel"] = df["JobLevel"].str.title()
df["Dept"] = df["Dept"].str.title()
df["EmpType"] = df["EmpType"].str.title()
df["CommuteMode"] = df["CommuteMode"].str.title()
df["EduLevel"] = df["EduLevel"].str.title()
df["haveOT"] = df["haveOT"].str.title()

#Capitalize 
df["Dept"] = df["Dept"].replace("It", "IT")

# %%
#Round decimals 
df["PhysicalActivityHours"] = df["PhysicalActivityHours"].round(0).astype("int64")
df["SleepHours"] = df["SleepHours"].round(0).astype("int64")
df["TrainingHoursPerYear"] = df["TrainingHoursPerYear"].round(0).astype("int64")
df
# Out:
#       EmpID  Gender  Age MaritalStatus        JobLevel  Experience       Dept  \
# 0         6    Male   32       Married             Mid           7         IT
# 1        11  Female   34       Married             Mid          12    Finance
# 2        33  Female   23        Single  Intern/Fresher           1  Marketing
# 3        20  Female   29       Married          Junior           6         IT
# 4        28   Other   23        Single          Junior           1      Sales
# ...     ...     ...  ...           ...             ...         ...        ...
# 3020   2070    Male   47       Married            Lead          16  Marketing
# 3021   2072  Female   47       Married            Lead           8         IT
# 3022   2145    Male   41       Married            Lead          17         IT
# 3023   2168  Female   54       Married            Lead          16         IT
# 3024   2183  Female   44       Married            Lead          22  Marketing
#
# ...

# %%
#Exploratory data analysis
#Summary statistic
df.describe()
# Out:
#              EmpID          Age   Experience          WLB      WorkEnv  \
# count  3025.000000  3025.000000  3025.000000  3025.000000  3025.000000
# mean   1513.000000    35.741818     9.082645     3.061157     3.029091
# std     873.386608    10.191833     7.073344     1.447001     1.415317
# min       1.000000    22.000000     0.000000     1.000000     1.000000
# 25%     757.000000    27.000000     3.000000     2.000000     2.000000
# 50%    1513.000000    34.000000     8.000000     3.000000     3.000000
# 75%    2269.000000    43.000000    14.000000     4.000000     4.000000
# max    3025.000000    60.000000    29.000000     5.000000     5.000000
#
#        PhysicalActivityHours     Workload       Stress   SleepHours  \
# count            3025.000000  3025.000000  3025.000000  3025.000000
# mean                2.035372     2.966612     1.736529     7.003967
# std                 1.007777     1.401486     1.064242     1.053457
# ...

# %%
#Save
df.to_excel("cleaned_data.xlsx", index=False)

# %%
#Reload into a new dataframe
df2 = pd.read_excel("cleaned_data.xlsx")

df2
# Out:
#       EmpID  Gender  Age MaritalStatus        JobLevel  Experience       Dept  \
# 0         6    Male   32       Married             Mid           7         IT
# 1        11  Female   34       Married             Mid          12    Finance
# 2        33  Female   23        Single  Intern/Fresher           1  Marketing
# 3        20  Female   29       Married          Junior           6         IT
# 4        28   Other   23        Single          Junior           1      Sales
# ...     ...     ...  ...           ...             ...         ...        ...
# 3020   2070    Male   47       Married            Lead          16  Marketing
# 3021   2072  Female   47       Married            Lead           8         IT
# 3022   2145    Male   41       Married            Lead          17         IT
# 3023   2168  Female   54       Married            Lead          16         IT
# 3024   2183  Female   44       Married            Lead          22  Marketing
#
# ...
